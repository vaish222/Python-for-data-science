# %%
import pandas as pd
import seaborn as sns

# %%
data_info = pd.read_csv('loan.csv',index_col='LoanStateNew')
# Out:
# /var/folders/p2/0q17jn4s2klcc73nrzg9lq_h0000gn/T/ipykernel_5096/3411965655.py:1: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_info = pd.read_csv('loan.csv',index_col='LoanStateNew')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data_info = pd.read_csv('loan.csv',index_col='LoanStateNew')
#
# ...

# %%
print(data_info.loc['revol_util']['Description'])

# %%
def feat_info(col_name):
    print(data_info.loc[col_name]['Description'])

# %%
feat_info('mort_acc')

# %%
sns.countplot(x='loan_status',data=df)

# %%
plt.figure(figsize=(12,4))
sns.distplot(df['loan_amnt'],kde=False,bins=40)

# %%
df.corr()

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(),annot=True,cmap='viridis')

# %%
plt.ylim(10,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.ylim(10,0)
#
# NameError: name 'plt' is not defined

# %%
feat_info('installment')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 feat_info('installment')
#
# Cell In[3], line 2, in feat_info(col_name)
#       1 def feat_info(col_name):
# ----> 2     print(data_info.loc[col_name]['Description'])
#
# NameError: name 'data_info' is not defined

# %%
feat_info('loan_amnt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 feat_info('loan_amnt')
#
# Cell In[3], line 2, in feat_info(col_name)
#       1 def feat_info(col_name):
# ----> 2     print(data_info.loc[col_name]['Description'])
#
# NameError: name 'data_info' is not defined

# %%
sns.scatterplot(x='installment',y='loan_amnt',data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sns.scatterplot(x='installment',y='loan_amnt',data=df)
#
# NameError: name 'df' is not defined

# %%
sns.boxplot(x='loan_status',y='loan_amnt',data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sns.boxplot(x='loan_status',y='loan_amnt',data=df)
#
# NameError: name 'df' is not defined

# %%
df.groupby('loan_status')['loan_amnt'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.groupby('loan_status')['loan_amnt'].describe()
#
# NameError: name 'df' is not defined

# %%
#unique possible grades and subgrades
df['sub_grade'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 #unique possible grades and subgrades
# ----> 2 df['sub_grade'].unique()
#
# NameError: name 'df' is not defined

# %%
df['grade'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df['grade'].unique()
#
# NameError: name 'df' is not defined

# %%
sns.countplot(x='grade',data=df,hue='loan_status')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 sns.countplot(x='grade',data=df,hue='loan_status')
#
# NameError: name 'df' is not defined

# %%
#display countplot per subgrade. explore loans amde per subgrade as well as separated based on loan_status
plt.figure(figsize=(12,4))
subgrade_order = sorted(df['sub_grade'].unique())
sns.countplot(x='sub_grade',data=df, order=subgrade_order,palette='coolwarm',hue='loan_status')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 #display countplot per subgrade. explore loans amde per subgrade as well as separated based on loan_status
# ----> 2 plt.figure(figsize=(12,4))
#       3 subgrade_order = sorted(df['sub_grade'].unique())
#       4 sns.countplot(x='sub_grade',data=df, order=subgrade_order,palette='coolwarm',hue='loan_status')
#
# NameError: name 'plt' is not defined

# %%
#looks like F anf G subgrades don't get paid back that often. Isolate those and recreate the countplot just for those subgrades
f_and_g = df[(df['grade']=='G') | (df['grade']=='F')]
plt.figure(figsize=(12,4))
subgrade_order = sorted(df['sub_grade'].unique())
sns.countplot(x='sub_grade',data=df, order=subgrade_order,palette='coolwarm',hue='loan_status')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 #looks like F anf G subgrades don't get paid back that often. Isolate those and recreate the countplot just for those subgrades
# ----> 2 f_and_g = df[(df['grade']=='G') | (df['grade']=='F')]
#       3 plt.figure(figsize=(12,4))
#       4 subgrade_order = sorted(df['sub_grade'].unique())
#
# NameError: name 'df' is not defined

# %%
#create new column called loan_repaid which will contian a 1 if the loan status was Fully Paid and a 0 if it was charged off
df['loan_repaid'] = df['loan_status'].map({'Fully Paid':1,'Charged off':0})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 #create new column called loan_repaid which will contian a 1 if the loan status was Fully Paid and a 0 if it was charged off
# ----> 2 df['loan_repaid'] = df['loan_status'].map({'Fully Paid':1,'Charged off':0})
#
# NameError: name 'df' is not defined

# %%
df[['loan_repaid','loan_status']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df[['loan_repaid','loan_status']]
#
# NameError: name 'df' is not defined

# %%
#bar plot showing correlation

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df.corr()
#
# NameError: name 'df' is not defined

# %%
df.corr['loan_repaid'].sort_values().drop('loan_repaid').plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df.corr['loan_repaid'].sort_values().drop('loan_repaid').plot(kind='bar')
#
# NameError: name 'df' is not defined

# %%
#remove or fill missing data

# %%
len(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 len(df)
#
# NameError: name 'df' is not defined

# %%
#create series that displayes the total count of missing values per column

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
#convert this series to be in term of percentage of the total DF

# %%
100 * df.isnull().sum() / len(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 100 * df.isnull().sum() / len(df)
#
# NameError: name 'df' is not defined

# %%
feat_info('emp_title')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 feat_info('emp_title')
#
# Cell In[3], line 2, in feat_info(col_name)
#       1 def feat_info(col_name):
# ----> 2     print(data_info.loc[col_name]['Description'])
#
# NameError: name 'data_info' is not defined

# %%
#unique employment job titles are there?

# %%
df['emp_title'].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df['emp_title'].nunique()
#
# NameError: name 'df' is not defined

# %%
df['emp_title'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df['emp_title'].value_counts()
#
# NameError: name 'df' is not defined

# %%
#realistically there are so many unique job titles to try to convert this to a dummy variable feature. Let's remove this column

# %%
df = df.drop('emp_title',axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df = df.drop('emp_title',axis=1)
#
# NameError: name 'df' is not defined

# %%
#countplot of the emp_length feature column.

# %%
sorted(df['emp_length'].dropna().unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 sorted(df['emp_length'].dropna().unique())
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='emp_length',data=df,order=emp_length_order,hue='loan_status')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 plt.figure(figsize=(12,4))
#       2 sns.countplot(x='emp_length',data=df,order=emp_length_order,hue='loan_status')
#
# NameError: name 'plt' is not defined

# %%
emp_co = df[df['loan_status']=='Charged Off'].groupby('emp_length').count()['loan_status']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 emp_co = df[df['loan_status']=='Charged Off'].groupby('emp_length').count()['loan_status']
#
# NameError: name 'df' is not defined

# %%
emp_fp = df[df['loan_status']=='Fully Paid'].groupby('emp_length').count()['loan_status']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 emp_fp = df[df['loan_status']=='Fully Paid'].groupby('emp_length').count()['loan_status']
#
# NameError: name 'df' is not defined

# %%
emp_lenght = emp_co/(emp_co+emp_fp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 emp_co/(emp_co+emp_fp)
#
# NameError: name 'emp_co' is not defined

# %%
emp_lenght.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 emp_lenght.plot(kind='bar')
#
# NameError: name 'emp_lenght' is not defined

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
#categorical data
#review the title column vs the purpose column. Is this repeated information?

# %%
df['purpose'].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df['purpose'].head(10)
#
# NameError: name 'df' is not defined

# %%
df['title'].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df['title'].head(10)
#
# NameError: name 'df' is not defined

# %%
feat_info('title')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 feat_info('title')
#
# Cell In[3], line 2, in feat_info(col_name)
#       1 def feat_info(col_name):
# ----> 2     print(data_info.loc[col_name]['Description'])
#
# NameError: name 'data_info' is not defined

# %%
feat_info('purpose')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 feat_info('purpose')
#
# Cell In[3], line 2, in feat_info(col_name)
#       1 def feat_info(col_name):
# ----> 2     print(data_info.loc[col_name]['Description'])
#
# NameError: name 'data_info' is not defined

# %%
#title column is simply a string subcategory/description of the purpose column. drop column title

# %%
df = df.drop('title',axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df = df.drop('title',axis=1)
#
# NameError: name 'df' is not defined

# %%
#find out what the mort_acc freature represents

# %%
feat_info('mort_acc')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 feat_info('mort_acc')
#
# Cell In[3], line 2, in feat_info(col_name)
#       1 def feat_info(col_name):
# ----> 2     print(data_info.loc[col_name]['Description'])
#
# NameError: name 'data_info' is not defined

# %%
#create a value_counts of the mort_Acc column

# %%
df['mort_acc'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 df['mort_acc'].value_counts()
#
# NameError: name 'df' is not defined

# %%
#there are many ways we could deal with this missing data. we could attempt to build a simple model to fill it in, such as linear model, we could just 
#fill it in based on the mean of the other columns, or could even bin the columns into categories and then set NaN as its own category. there is no 100%
# correct approach. review the other columns to see which most highly correlates to mort_acc

# %%
df.corr()['mort_acc'].sort_values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df.corr()['mort_acc'].sort_values()
#
# NameError: name 'df' is not defined

# %%
#looks like the total_acc feature correlates with the mort_acc, this makes sense! Let's try this fillna() approach. We will group the dataframe
#by the total_acc and calculate the mean value for the mort_acc per total_acc entry.

# %%
total_acc_avg = df.groupby('total_acc').mean()['mort_acc']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 total_acc_avg = df.groupby('total_acc').mean()['mort_acc']
#
# NameError: name 'df' is not defined

# %%
def fill_mort_acc(total_acc,mort_acc):
    if np.isnan(mort_acc):
        return total_acc_avg[total_acc]
    else:
        return mort_acc

# %%
df.apply(lambda x: fill_mort_acc(x['total_acc'],x['mort_acc']),axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df.apply(lambda x: fill_mort_acc(x['total_acc'],x['mort_acc']),axis=1)
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
df = df.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df = df.dropna()
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
#list all the columns that are currently non-numeric

# %%
df.select_dtypes(['object']).columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df.select_dtypes(['object']).columns
#
# NameError: name 'df' is not defined

# %%
feat_info('term')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 feat_info('term')
#
# Cell In[3], line 2, in feat_info(col_name)
#       1 def feat_info(col_name):
# ----> 2     print(data_info.loc[col_name]['Description'])
#
# NameError: name 'data_info' is not defined

# %%
df['term'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 df['term'].value_counts()
#
# NameError: name 'df' is not defined

# %%
df['term'] = df['term'].apply(lambda term: int(term[:3]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 df['term'] = df['term'].apply(lambda term: int(term[:3]))
#
# NameError: name 'df' is not defined

# %%
df['term'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 df['term'].value_counts()
#
# NameError: name 'df' is not defined

# %%
#grade is the part of the sub_grade, so just drop the grade feature

# %%
df = df.drop('grade',axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 df = df.drop('grade',axis=1)
#
# NameError: name 'df' is not defined

# %%
#convert the subgrade into dummy variables. Then concatenate these new columns to the original dataframe. Remember to drop the original subgrade column and 
#to add drop_first=True to your get_dummies call.

# %%
dummies = pd.get_dummies(df['sub_grade'],drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 dummies = pd.get_dummies(df['sub_grade'],drop_first=True)
#
# NameError: name 'df' is not defined

# %%
df = pd.concat([df.drop('sub_grade',axis=1),dummies],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 df = pd.concat([df.drop('sub_grade',axis=1),dummies],axis=1)
#
# NameError: name 'df' is not defined

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
#convert these columns into dummy variables and concatenate them with the original dataframe. Remember to set drop_first=True and to drop the 
#original columns

# %%
dummies = pd.get_dummies(df[['verification_status','application_type','initial_list_status','purpose']],drop_first=True)
df = pd.concat([df.drop(['verification_status','application_type','initial_list_status','purpose'],axis=1),dummies],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 dummies = pd.get_dummies(df[['verification_status','application_type','initial_list_status','purpose']],drop_first=True)
#       2 df = pd.concat([df.drop(['verification_status','application_type','initial_list_status','purpose'],axis=1),dummies],axis=1)
#
# NameError: name 'df' is not defined

# %%
#review the value_counts() for the home_ownership column

# %%
df['home_ownership'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 df['home_ownership'].value_counts()
#
# NameError: name 'df' is not defined

# %%
#convert these to dummy variables but replace none and any with other, so that we end up with just 4 categories, mortgage, rent, own, other
#then concatenate them with the original dataframe. Remember to set drop_first=true and to drop the original columns

# %%
df['home_ownership'] = df['home_ownership'].replace(['NONE','ANY'],'OTHER')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 df['home_ownership'] = df['home_ownership'].replace(['NONE','ANY'],'OTHER')
#
# NameError: name 'df' is not defined

# %%
df['home_ownership'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 df['home_ownership'].value_counts()
#
# NameError: name 'df' is not defined

# %%
dummies = pd.get_dummies(df['home_ownership'],drop_first=True)
df = pd.concat([df.drop('home_ownership',axis=1),dummies],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 dummies = pd.get_dummies(df['home_ownership'],drop_first=True)
#       2 df = pd.concat([df.drop('home_ownership',axis=1),dummies],axis=1)
#
# NameError: name 'df' is not defined

# %%
#address
# let's feature engineer a zipcode column from the address in the data set. Create a column called zip_code that
#extracts the zipcode from the address column

# %%
df['zip_code'] = df['address'].apply(lambda address: address[-5:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 df['zip_code'] = df['address'].apply(lambda address: address[-5:])
#
# NameError: name 'df' is not defined

# %%
df['zip_code'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 df['zip_code'].value_counts()
#
# NameError: name 'df' is not defined

# %%
#make zipcode column into dummy variables using pandas.Concatenate the result and drop the original zip_code column along with 
#dropping the address column
dummies = pd.get_dummies(df['zip_code'],drop_first=True)
df = pd.concat([df.drop('zip_code',axis=1),dummies],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[116], line 3
#       1 #make zipcode column into dummy variables using pandas.Concatenate the result and drop the original zip_code column along with
#       2 #dropping the address column
# ----> 3 dummies = pd.get_dummies(df['zip_code'],drop_first=True)
#       4 df = pd.concat([df.drop('zip_code',axis=1),dummies],axis=1)
#
# NameError: name 'df' is not defined

# %%
df = df.drop('adress',axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 df = df.drop('adress',axis=1)
#
# NameError: name 'df' is not defined

# %%
#this would be data leakage we wouldn't know beforehand whether or not a loan would be issued when using our model
# so in theory we wouldn't have an issue_date,drop this feature

# %%
feat_info('issue_d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 feat_info('issue_d')
#
# Cell In[3], line 2, in feat_info(col_name)
#       1 def feat_info(col_name):
# ----> 2     print(data_info.loc[col_name]['Description'])
#
# NameError: name 'data_info' is not defined

# %%
df = df.drop('issue_d',axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 df = df.drop('issue_d',axis=1)
#
# NameError: name 'df' is not defined

# %%
#this appears to be a historical time stamp feature. Extract the year from this feature using a apply function then convert
#it to a numeric feature, Set this new data to a feature column called 'earliest_cr_year'. Then Drop the earliest_cr_line feature

# %%
feature_info('earliest_cr_year')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 feature_info('earliest_cr_year')
#
# NameError: name 'feature_info' is not defined

# %%
df['earliest_cr_year'] = df['earliest_cr_year'].apply(lambda date:int(date[-4:]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 df['earliest_cr_year'] = df['earliest_cr_year'].apply(lambda date:int(date[-4:]))
#
# NameError: name 'df' is not defined

# %%
df['earliest_cr_year']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 df['earliest_cr_year']
#
# NameError: name 'df' is not defined

# %%
from sklearn.model_selection import train_test_split

# %%
#drop the loan_status column we created earlier, since its a duplicate of the loan_repaid column. We'll use the loan_repaid column
# since its already in 0s and 1s

# %%
df = df.drop('loan_status',axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 df = df.drop('loan_status',axis=1)
#
# NameError: name 'df' is not defined

# %%
x = df.drop('loan_repaid',axis=1).values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 x = df.drop('loan_repaid',axis=1).values
#
# NameError: name 'df' is not defined

# %%
y=df['loan_repaid'].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 y=df['loan_repaid'].values
#
# NameError: name 'df' is not defined

# %%
df = df.sample(frac=0.1,random_state=101)
print(len(df))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 df = df.sample(frac=0.1,random_state=101)
#       2 print(len(df))
#
# NameError: name 'df' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)
#
# NameError: name 'X' is not defined

# %%
#normalize the data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 X_train = scaler.fit_transform(X_train)
#
# NameError: name 'X_train' is not defined

# %%
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 X_test = scaler.transform(X_test)
#
# NameError: name 'X_test' is not defined

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
model = Sequential()
model.add(Dense(78,activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(39,activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(19,activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(1,activation = 'sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = Sequential()
#       2 model.add(Dense(78,activation = 'relu'))
#       3 model.add(Dropout(0.2))
#
# NameError: name 'Sequential' is not defined

# %%
X_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 X_train.shape
#
# NameError: name 'X_train' is not defined

# %%
model.fit(x=X_train,y=y_train,epochs=25,batch_size=256,validation_data=(X_test,y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model.fit(x=X_train,y=y_train,epochs=25,batch_size=256,validation_data=(X_test,y_test))
#
# NameError: name 'model' is not defined

# %%
from tensorflow.keras.models import load_model

# %%
model.save('myfavoritemodel.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.save('myfavoritemodel.h5')
#
# NameError: name 'model' is not defined

# %%
losses = pd.DataFram(model.history.history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 losses = pd.DataFram(model.history.history)
#
# NameError: name 'pd' is not defined

# %%
losses.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 losses.plot()
#
# NameError: name 'losses' is not defined

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
predictions = model.predict_classes(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 predictions = model.predict_classes(X_test)
#
# NameError: name 'model' is not defined

# %%
print(classification_report(y_true,predictions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(classification_report(y_true,predictions))
#
# NameError: name 'y_true' is not defined

# %%
df['loan_repaid'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df['loan_repaid'].value_counts()
#
# NameError: name 'df' is not defined

# %%
confusion_matrix(y_test,predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 confusion_matrix(y_test,predictions)
#
# NameError: name 'y_test' is not defined

# %%
#given the customer below, would you offer this person a loan?

# %%
import random
random.seed(101)
random_ind = random.randint(0,len(df))

new_customer = df.drop('loan_repaid',axis=1).iloc[random_ind]
new_customer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 import random
#       2 random.seed(101)
# ----> 3 random_ind = random.randint(0,len(df))
#       5 new_customer = df.drop('loan_repaid',axis=1).iloc[random_ind]
#       6 new_customer
#
# NameError: name 'df' is not defined

# %%
new_customer = scaler.transform(new_customer.values.reshape(1,78))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 new_customer = scaler.transform(new_customer.values.reshape(1,78))
#
# NameError: name 'scaler' is not defined

# %%
model.predict_classes(new_customer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model.predict_classes(new_customer)
#
# NameError: name 'model' is not defined

# %%
#now check did this person actually end up paying back their loan

# %%
df.iloc[random_ind]['loan_repaid']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.iloc[random_ind]['loan_repaid']
#
# NameError: name 'df' is not defined
